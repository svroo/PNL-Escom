# %% [markdown]
# ## Transformacion
#
# $TF = term frquency$
#
# $(1, 0, 3, 100, \dots) stopword=100$
#
# $tf_1 (word) = log(1+centro de word)$
#
# $tf_2 (word) = \frac{(k+1) * conteo}{conteo + k}$
#
# $(tf(w_1), tf(w_2)\dots)$
#
#
# Pero las palabras comunes no discriminan los significados y no dejan que obtengamos todo. A mayor frecuencia menos relevante
#
# $$idf(word) = log\left[\frac{M+1}{\# de documentos con word}\right]$$
#
# $Vector Final : (tf*idf, \dots, \dots)\rightarrow normalizados$
#
# Contextos de palabras:
# contextos de diferentes parabras
#
# ### BM25
# $y=\frac{(k+1)x}{x+k}$
#
# ### BM25 Retrieval MOdel for paradimatic Relation Mining
#
# Es una de las formulas de $tf_3(word) = BM25$ + solucion de longitud diferente de docs
#
# $d1=(x_1, \dots, x_N)$
#
# $\overrightarrow{v_1} = (idf*BM25,\dots, \dots)$ normalizados
#
# $\overrightarrow{v_2} = (idf * BM25)$ normalizado
#
# $cos(\overrightarrow{v_1}, \overrightarrow{v_2})$
#
# $BM25(w_i,dl) = \frac{(k+1)c(w_i,dl)}{c(w_i,dl)+k(l-b+b*|dl|/avdl)}$
# |d1| cardinalidad de conjuntos o document length
#
# $x_i = \frac{BM25(w_i,dl)}{\sum_{j=1}^{N} BM25(w_j,dl)}$
#
# $b\in[0,1] \\ k\in[0,+\inf]$ algunas veces se usa el valor 1.2
#
# $d2=(y_1, \dots, y_N) y_i$ is defined similarly
#
# $dim(d_1,d_2) = \sum_{i=1}^N IDF (w_i)x_i y_i$
#
# $x_i \rightarrow$ BM25 normalizado $y_i \rightarrow$ BM25 normalizado
#
# producto punto
#
# k $\leftarrow$ modifica la pendiente, modifica el castigo de las palabras frecuentes
#
# ```python
# np.dot(idf, np.multiply(v1, v2))
# ```
#
# Para el jueves revisará la salida de este programa
